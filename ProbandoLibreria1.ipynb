# %% [markdown]
# <a href="https://colab.research.google.com/github/Anderson-Quintero/HexSample/blob/main/ProbandoLibreria1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Anderson-Quintero/HexSample.git
from HexSample import TituloLibreria as Hs
import matplotlib.pyplot as plt
import numpy as np
import cv2
# Out:
# Cloning into 'HexSample'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), done.

# %% [markdown]
# # Sistema de coordenadas

# %%
for i in range(5):
    for j in range(5):
        print((j,i),"Se transforma en: ",Hs.HexImage.Cart2Hex(j,i))
# Out:
# (0, 0) Se transforma en:  (0, 0.0, 0.0)
# (1, 0) Se transforma en:  (0, 0.0, 1.0)
# (2, 0) Se transforma en:  (0, 0.0, 2.0)
# (3, 0) Se transforma en:  (0, 0.0, 3.0)
# (4, 0) Se transforma en:  (0, 0.0, 4.0)
# (0, 1) Se transforma en:  (1, 0.0, 0.0)
# (1, 1) Se transforma en:  (1, 0.0, 1.0)
# (2, 1) Se transforma en:  (1, 0.0, 2.0)
# (3, 1) Se transforma en:  (1, 0.0, 3.0)
# (4, 1) Se transforma en:  (1, 0.0, 4.0)
# (0, 2) Se transforma en:  (0, 1.0, 0.0)
# (1, 2) Se transforma en:  (0, 1.0, 1.0)
# (2, 2) Se transforma en:  (0, 1.0, 2.0)
# (3, 2) Se transforma en:  (0, 1.0, 3.0)
# (4, 2) Se transforma en:  (0, 1.0, 4.0)
# (0, 3) Se transforma en:  (0, 2.0, 0.0)
# (1, 3) Se transforma en:  (0, 2.0, 1.0)
# (2, 3) Se transforma en:  (0, 2.0, 2.0)
# (3, 3) Se transforma en:  (0, 2.0, 3.0)
# (4, 3) Se transforma en:  (0, 2.0, 4.0)
# (0, 4) Se transforma en:  (1, 2.0, 0.0)
# (1, 4) Se transforma en:  (1, 2.0, 1.0)
# (2, 4) Se transforma en:  (1, 2.0, 2.0)
# ...

# %%
for r in range(3):
    for a in range(2):
        for c in range(5):
            print((a,r,c),"Se transforma en: ",Hs.HexImage.Hex2Cart(a,r,c))
# Out:
# (0, 0, 0) Se transforma en:  (0, 0)
# (0, 0, 1) Se transforma en:  (1, 0)
# (0, 0, 2) Se transforma en:  (2, 0)
# (0, 0, 3) Se transforma en:  (3, 0)
# (0, 0, 4) Se transforma en:  (4, 0)
# (1, 0, 0) Se transforma en:  (0, 1)
# (1, 0, 1) Se transforma en:  (1, 1)
# (1, 0, 2) Se transforma en:  (2, 1)
# (1, 0, 3) Se transforma en:  (3, 1)
# (1, 0, 4) Se transforma en:  (4, 1)
# (0, 1, 0) Se transforma en:  (0, 2)
# (0, 1, 1) Se transforma en:  (1, 2)
# (0, 1, 2) Se transforma en:  (2, 2)
# (0, 1, 3) Se transforma en:  (3, 2)
# (0, 1, 4) Se transforma en:  (4, 2)
# (1, 1, 0) Se transforma en:  (0, 3)
# (1, 1, 1) Se transforma en:  (1, 3)
# (1, 1, 2) Se transforma en:  (2, 3)
# (1, 1, 3) Se transforma en:  (3, 3)
# (1, 1, 4) Se transforma en:  (4, 3)
# (0, 2, 0) Se transforma en:  (0, 3)
# (0, 2, 1) Se transforma en:  (1, 3)
# (0, 2, 2) Se transforma en:  (2, 3)
# (0, 2, 3) Se transforma en:  (3, 3)
# (0, 2, 4) Se transforma en:  (4, 3)
# (1, 2, 0) Se transforma en:  (0, 4)
# ...

# %% [markdown]
# # Cargar imagen

# %%
img = Hs.HexImage.read('/content/HexSample/lena.jpg')

# %% [markdown]
# # Muestreo 1

# %%
img = Hs.HexImage.read('/content/HexSample/lena.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
BinarioHexa = Hs.HexImage.sqr2hex(img,1,4)

# %%
plt.figure(figsize=(10,10))
plt.imshow(BinarioHexa,cmap='Greys', interpolation='nearest')

# %%
Hs.HexImage.write(BinarioHexa,'lenaBinariaHexagonal.jpg')

# %% [markdown]
# ## Usando Color

# %%
img = Hs.HexImage.read('/content/HexSample/lena.jpg')
ColorHexa = Hs.HexImage.sqr2hex(img,1,4)

# %%
plt.figure(figsize=(10,10))
plt.imshow(ColorHexa,cmap='Greys', interpolation='nearest')

# %%
Hs.HexImage.write(ColorHexa,'lenaHexagonal.jpg')

# %% [markdown]
# ## No hexagonal

# %%
img = Hs.HexImage.read('/content/HexSample/lena.jpg')
Reticula1 = Hs.HexImage.sqr2hex(img,1.3,4)
Reticula2 = Hs.HexImage.sqr2hex(img,2.3,4)
Reticula3 = Hs.HexImage.sqr2hex(img,3.3,4)

# %%
plt.figure(figsize=(10,10))
plt.imshow(Reticula1,cmap='Greys', interpolation='nearest')

# %%
plt.figure(figsize=(10,10))
plt.imshow(Reticula2,cmap='Greys', interpolation='nearest')

# %%
plt.figure(figsize=(10,10))
plt.imshow(Reticula3,cmap='Greys', interpolation='nearest')

# %%
Hs.HexImage.write(Reticula1,'Ret1.jpg')
Hs.HexImage.write(Reticula2,'Ret2.jpg')
Hs.HexImage.write(Reticula3,'Ret3.jpg')

# %% [markdown]
# ## Filtrado

# %%
Filtro = np.array([[0, -1, 0], [-1, 4, -1], [0, -1, 0]])
FiltroHex = Hs.HexImage.sqr2hex(Filtro,1,4)

img = Hs.HexImage.read('/content/HexSample/lena.jpg')
Imagen = Hs.HexImage.sqr2hex(img,1,4)

# %%
Filtrado = Hs.HexImage.HexConv(Imagen,FiltroHex)

# %%
Hs.HexImage.write(Filtrado,'ImagenFiltrada.jpg')

# %% [markdown]
# # Muestreo Hexagonal Método 2

# %%
img = Hs.HexImage.read('/content/HexSample/lena.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
BinarioHexagonal=Hs.HexImage.HexSample(img)

# %%
plt.figure(figsize=(10,10))
plt.imshow(BinarioHexagonal,cmap='Greys', interpolation='nearest')

# %%
Hs.HexImage.write(BinarioHexagonal,'BinarioFiltradaHex.jpg')

# %% [markdown]
# ## Usando color

# %%
img = Hs.HexImage.read('/content/HexSample/lena.jpg')
Hexagonal= Hs.HexImage.HexSample(img)

# %%
plt.figure(figsize=(10,10))
plt.imshow(Hexagonal,cmap='Greys', interpolation='nearest')

# %%
Hs.HexImage.write(Hexagonal,'ColorFiltradaHex.jpg')

# %% [markdown]
# # Muestreo Rectangular

# %%
img = Hs.HexImage.read('/content/HexSample/lena.jpg')
Rectangular3=Hs.HexImage.RecSample(img,4,3)

# %%
plt.figure(figsize=(10,10))
plt.imshow(Rectangular3,cmap='Greys', interpolation='nearest')

# %%
Hs.HexImage.write(Rectangular3,'ColorFiltradaRec.jpg')

# %% [markdown]
# ## Sin corrimiento

# %%
img = Hs.HexImage.read('/content/HexSample/lena.jpg')
Rectangular=Hs.HexImage.RecSample(img,4,0)

# %%
plt.figure(figsize=(10,10))
plt.imshow(Rectangular,cmap='Greys', interpolation='nearest')

# %%
Hs.HexImage.write(Rectangular3,'ColorFiltradaRec0.jpg')
